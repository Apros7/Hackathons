# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# - estimates of diabetes prevalence worldwide for individuals aged 20 to 79
# - data on the number of people with diabetes in thousands, categorised by region and country.
# - The dataset spans several years (2000, 2011, 2021, 2030, and 2045),

# %%
all_data = pd.read_excel("../Case/Health Data from International Diabetes Foundation.xlsx", header=1, sheet_name=None)

# %%
all_data.keys()
# Out:
# dict_keys(['People with diabetes (1000s)', 'Diabetes prevalence (%)', 'People undiagnosed (1000s)', 'People undiagnosed (proportion)', 'Deaths attributable to diabetes', 'Diabetes-related deaths (propo)', 'Total diabetes costs (USD mill)', 'Diabetes costs per person (USD)', 'People with Type 1 (in 1000s)', 'New cases of Type 1 (in 1000s)'])

# %% [markdown]
# People with diabetes (1000s)

# %%
data = all_data["People with diabetes (1000s)"]
data.head(150)
# Out:
#        #                        Region             Country/Territory  \
# 0      1                        Africa                        Africa
# 1      2                        Europe                        Europe
# 2      3  Middle East and North Africa  Middle East and North Africa
# 3      4   North America and Caribbean   North America and Caribbean
# 4      5     South and Central America     South and Central America
# ..   ...                           ...                           ...
# 145  146               Western Pacific                       Myanmar
# 146  147                        Africa                       Namibia
# 147  148               Western Pacific                         Nauru
# 148  149               South-East Asia                         Nepal
# 149  150                        Europe                   Netherlands
#
#          2000      2011      2021      2030       2045     Type
# 0     2,532.9  14,700.0  23,633.9  33,446.0   55,254.4   Region
# 1    22,373.1  52,770.8  61,425.1  67,000.0   69,000.0   Region
# 2    17,007.6  32,600.0  72,671.9  95,000.0  135,700.0   Region
# 3    21,375.1  37,700.0  50,547.0  57,000.0   63,000.0   Region
# 4     8,553.3  25,121.5  32,497.1  40,000.0   49,000.0   Region
# ..        ...       ...       ...       ...        ...      ...
# 145         -   2,103.7   2,346.6   2,791.4    3,437.9  Country
# 146         -      74.1        75     102.5      166.4  Country
# 147         -       1.2       1.5       1.7        1.8  Country
# 148         -     488.2   1,133.5   1,553.4    2,180.1  Country
# 149     415.9     881.6       857     910.4      894.7  Country
#
# [150 rows x 9 columns]

# %%
def get_value(v):
    if v == "-":
        return 0
    if isinstance(v, str):
       v = v.replace(",", "") 
    return float(v)

# %%
regions = {name: {} for name in data.Region.unique()}
regions
# Out:
# {'Africa': {},
#  'Europe': {},
#  'Middle East and North Africa': {},
#  'North America and Caribbean': {},
#  'South and Central America': {},
#  'South-East Asia': {},
#  'Western Pacific': {}}

# %%
regions = {name: {} for name in data.Region.unique()}
total = {name: [] for name in data.Region.unique()}

for row in data.iterrows():
    row = row[1]
    if row["Region"] == row["Country/Territory"]:
        total[row["Region"]].append([get_value(row[2000]), get_value(row[2011]), get_value(row[2021]), get_value(row[2030]), get_value(row[2045])])
        continue
    reqion_dict = regions[row["Region"]]
    reqion_dict["2000"] = reqion_dict.get("2000", 0) + get_value(row[2000])
    reqion_dict["2011"] = reqion_dict.get("2011", 0) + get_value(row[2011])
    reqion_dict["2021"] = reqion_dict.get("2021", 0) + get_value(row[2021])
    reqion_dict["2030"] = reqion_dict.get("2030", 0) + get_value(row[2030])
    reqion_dict["2045"] = reqion_dict.get("2045", 0) + get_value(row[2045])

# %%
total
# Out:
# {'Africa': [[2532.9, 14700.0, 23633.9, 33446.0, 55254.4]],
#  'Europe': [[22373.1, 52770.8, 61425.1, 67000.0, 69000.0]],
#  'Middle East and North Africa': [[17007.6,
#    32600.0,
#    72671.9,
#    95000.0,
#    135700.0]],
#  'North America and Caribbean': [[21375.1,
#    37700.0,
#    50547.0,
#    57000.0,
#    63000.0]],
#  'South and Central America': [[8553.3, 25121.5, 32497.1, 40000.0, 49000.0]],
#  'South-East Asia': [[34882.2, 71406.9, 90204.5, 113300.0, 151500.0]],
#  'Western Pacific': [[44097.9, 131895.1, 205640.2, 238300.0, 260200.0]]}

# %%
regions
# Out:
# {'Africa': {'2000': 2532.8,
#   '2011': 14700.400000000003,
#   '2021': 23633.9,
#   '2030': 33172.299999999996,
#   '2045': 54896.8},
#  'Europe': {'2000': 22467.799999999996,
#   '2011': 52771.000000000015,
#   '2021': 61425.5,
#   '2030': 66585.30000000002,
#   '2045': 69181.09999999999},
#  'Middle East and North Africa': {'2000': 17007.699999999997,
#   '2011': 32602.8,
#   '2021': 72671.89999999998,
#   '2030': 94884.90000000002,
#   '2045': 135746.5},
#  'North America and Caribbean': {'2000': 21399.8,
#   '2011': 37921.4,
#   '2021': 50546.9,
#   '2030': 56592.90000000001,
#   '2045': 62763.8},
#  'South and Central America': {'2000': 8528.6,
#   '2011': 25133.699999999997,
#   '2021': 32497.099999999995,
#   '2030': 39773.8,
#   '2045': 48890.29999999999},
#  'South-East Asia': {'2000': 34882.1,
#   '2011': 71406.9,
#   '2021': 90204.29999999999,
#   '2030': 113279.0,
#   '2045': 151511.40000000002},
#  'Western Pacific': {'2000': 44097.899999999994,
#   '2011': 131896.40000000002,
#   '2021': 205640.3,
#   '2030': 238343.50000000003,
#   '2045': 260241.80000000005}}

# %%
# data = all_data["Diabetes costs per person (USD)"]
data = all_data["Diabetes prevalence (%)"]
regions = {name: {} for name in data.Region.unique()}

years = ['2000', '2011', '2021', '2030', '2045']

for row in data.iterrows():
    row = row[1]
    reqion_dict = regions[row["Region"]]
    reqion_dict["2000"] = reqion_dict.get("2000", 0) + get_value(row[2000])
    reqion_dict["2011"] = reqion_dict.get("2011", 0) + get_value(row[2011])
    reqion_dict["2021"] = reqion_dict.get("2021", 0) + get_value(row[2021])
    reqion_dict["2030"] = reqion_dict.get("2030", 0) + get_value(row[2030])
    reqion_dict["2045"] = reqion_dict.get("2045", 0) + get_value(row[2045])

plt.figure(figsize=(10, 6))

for region, values in regions.items():
    plt.plot(years, list(values.values()), label=region)

plt.title('Population Projection by Region')
plt.xlabel('Year')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
years = ['2000', '2011', '2021', '2030', '2045']

plt.figure(figsize=(10, 6))

for region, values in regions.items():
    plt.plot(years, list(values.values()), label=region)

plt.title('Population Projection by Region')
plt.xlabel('Year')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
data[data["Region"] == "Western Pacific"]
# Out:
#        #           Region                      Country/Territory      2000  \
# 6      7  Western Pacific                        Western Pacific  44,097.9
# 10    11  Western Pacific                         American Samoa         -
# 18    19  Western Pacific                              Australia     781.3
# 36    37  Western Pacific                      Brunei Darussalam         -
# 41    42  Western Pacific                               Cambodia         -
# 49    50  Western Pacific                                  China  22,564.8
# 50    51  Western Pacific                   China, Hong Kong SAR     614.4
# 51    52  Western Pacific                       China, Macao SAR      34.5
# 55    56  Western Pacific                           Cook Islands         -
# 63    64  Western Pacific  Democratic People's Republic of Korea         -
# 78    79  Western Pacific                                   Fiji      42.3
# 82    83  Western Pacific                       French Polynesia         -
# 92    93  Western Pacific                                   Guam         -
# 103  104  Western Pacific                              Indonesia   5,654.3
# 111  112  Western Pacific                                  Japan   7,113.2
# 115  116  Western Pacific                               Kiribati         -
# 118  119  Western Pacific       Lao People's Democratic Republic         -
# 129  130  Western Pacific                               Malaysia     596.7
# 133  134  Western Pacific                       Marshall Islands         -
# 139  140  Western Pacific       Micronesia (Federated States of)         -
# 141  142  Western Pacific                               Mongolia         -
# 145  146  Western Pacific                                Myanmar         -
# 147  148  Western Pacific                                  Nauru         -
# 151  152  Western Pacific                          New Caledonia         -
# 152  153  Western Pacific                            New Zealand     104.3
# 156  157  Western Pacific                                   Niue         -
# 157  158  Western Pacific               Northern Mariana Islands         -
# 162  163  Western Pacific                                  Palau         -
# 164  165  Western Pacific                       Papua New Guinea     378.3
# 167  168  Western Pacific                            Philippines   1,242.2
# 173  174  Western Pacific                      Republic of Korea   1,986.0
# 181  182  Western Pacific                                  Samoa         -
# 189  190  Western Pacific                              Singapore     282.1
# 192  193  Western Pacific                        Solomon Islands         -
# 204  205  Western Pacific                                 Taiwan   1,206.9
# 206  207  Western Pacific                               Thailand   1,489.1
# 207  208  Western Pacific                            Timor-Leste         -
# 209  210  Western Pacific                                Tokelau         -
# 210  211  Western Pacific                                  Tonga       7.5
# 215  216  Western Pacific                                 Tuvalu         -
# 225  226  Western Pacific                                Vanuatu         -
# 227  228  Western Pacific                               Viet Nam         -
#
#           2011       2021       2030       2045     Type
# 6    131,895.1  205,640.2  238,300.0  260,200.0   Region
# 10           -        7.8        8.4        8.9  Country
# 18     1,292.1    1,491.8    1,693.0    1,935.2  Country
# 36        19.3         35         42       47.3  Country
# 41       199.4        596      776.2    1,094.6  Country
# 49    90,045.1  140,869.6  164,069.5  174,433.5  Country
# 50       525.4        686        837      831.1  Country
# 51        32.7       50.9       69.5       81.3  Country
# 55           1          -          -          -  Country
# 63     1,507.5    1,847.1    2,070.6    2,295.9  Country
# 78        55.4       99.2        116      139.7  Country
# 82        14.9       52.1         60       68.1  Country
# 92        10.3       23.3       26.6       29.6  Country
# 103    7,291.9   19,465.1   23,328.0   28,569.9  Country
# 111   10,674.3   11,005.0   10,542.7   10,117.9  Country
# 115         15       14.1       18.1       25.2  Country
# 118       90.1      214.8      289.7      432.7  Country
# 129    2,029.9    4,431.5    5,024.9    6,465.4  Country
# 133          7        9.1       10.7       13.1  Country
# 139        7.7        8.7       10.3       13.2  Country
# 141      117.5      150.8      174.8      210.6  Country
# 145    2,103.7    2,346.6    2,791.4    3,437.9  Country
# 147        1.2        1.5        1.7        1.8  Country
# 151       14.6       49.8       57.2       67.7  Country
# 152      312.1      268.7      296.8      319.6  Country
# 156        0.1          -          -          -  Country
# 157          -        8.3        9.2       10.1  Country
# 162        1.4        1.9          2        2.1  Country
# 164      216.8        724      901.4    1,229.7  Country
# 167    4,219.7    4,303.9    5,456.3    7,503.9  Country
# 173    3,186.4    3,511.8    3,934.2    3,860.9  Country
# 181        6.6        7.7        9.3       11.7  Country
# 189      426.7      711.8      872.3      898.9  Country
# 192       34.5       53.3         71      110.4  Country
# 204    1,664.5    2,457.2    2,979.4    3,030.7  Country
# 206    4,014.3    6,066.6    6,735.5    6,783.7  Country
# 207         30       46.3       59.1       89.8  Country
# 209        0.1          -          -          -  Country
# 210        6.1        7.4        8.5       10.7  Country
# 215        1.1        1.6        1.9        2.4  Country
# 225       17.3       19.9       26.7       41.3  Country
# 227    1,702.7    3,994.1    4,961.6    6,015.3  Country

# %% [markdown]
# Diabetes prevalence (%)

# %%
data = all_data["Diabetes prevalence (%)"]
data
# Out:
#        #                        Region                   Country/Territory  \
# 0      1                        Africa                              Africa
# 1      2                        Europe                              Europe
# 2      3  Middle East and North Africa        Middle East and North Africa
# 3      4   North America and Caribbean         North America and Caribbean
# 4      5     South and Central America           South and Central America
# ..   ...                           ...                                 ...
# 226  227     South and Central America  Venezuela (Bolivarian Republic of)
# 227  228               Western Pacific                            Viet Nam
# 228  229  Middle East and North Africa                               Yemen
# 229  230                        Africa                              Zambia
# 230  231                        Africa                            Zimbabwe
#
#     2000  2011  2021  2030  2045     Type
# 0    1.2   4.5   5.3   5.5   5.6   Region
# 1    4.9   6.7     7     8   8.7   Region
# 2    7.7    11  18.1  19.6  20.4   Region
# 3    7.8  10.7  11.9  13.3  14.2   Region
# 4    3.7   9.2   8.2   9.2   9.9   Region
# ..   ...   ...   ...   ...   ...      ...
# 226    -  10.2   9.6  11.9  12.7  Country
# 227    -   3.2   6.1   6.7   7.1  Country
# 228    -   9.6   5.4   5.7   5.7  Country
# 229    -   4.8  11.9  13.2    14  Country
# 230    -   9.8   2.1   2.2   2.3  Country
#
# [231 rows x 9 columns]

# %%
data.notna().sum()
# Out:
# #                    231
# Region               231
# Country/Territory    231
# 2000                 231
# 2011                 231
# 2021                 231
# 2030                 231
# 2045                 231
# Type                 231
# dtype: int64

# %%
regions = {name: {} for name in data.Region.unique()}

for row in data.iterrows():
    row = row[1]
    reqion_dict = regions[row["Region"]]
    reqion_dict["2000"] = reqion_dict.get("2000", 0) + get_value(row[2000])
    reqion_dict["2011"] = reqion_dict.get("2011", 0) + get_value(row[2011])
    reqion_dict["2021"] = reqion_dict.get("2021", 0) + get_value(row[2021])
    reqion_dict["2030"] = reqion_dict.get("2030", 0) + get_value(row[2030])
    reqion_dict["2045"] = reqion_dict.get("2045", 0) + get_value(row[2045])
